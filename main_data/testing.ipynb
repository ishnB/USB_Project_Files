# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("filtered_bulk_r.csv")

# %%
df = df.round(4)

# %%
df.head()
# Out:
#    fl_dur  tot_fw_pk  tot_bw_pk  fw_pkt_l_max  fw_pkt_l_min  fw_pkt_l_avg  \
# 0  0.0001          2          2            79            48          63.5
# 1  0.0002          2          2            79            48          63.5
# 2  0.0001          2          2            79            48          63.5
# 3  0.0001          2          2            79            48          63.5
# 4  0.0002          2          2            79            48          63.5
#
#    fw_pkt_l_std  bw_pkt_l_max  bw_pkt_l_min  bw_pkt_l_mean  ...  bw_iat_tot  \
# 0       21.9203            61            48           54.5  ...         0.0
# 1       21.9203            61            48           54.5  ...         0.0
# 2       21.9203            61            48           54.5  ...         0.0
# 3       21.9203            61            48           54.5  ...         0.0
# 4       21.9203            61            48           54.5  ...         0.0
#
# ...

# %%
df.to_csv("filtered_bulk_rounded.csv", index=False)
